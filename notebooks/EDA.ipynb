# %% [markdown]
# # Leaf Disease Dataset EDA Analysis
# ## Step 1: Project Setup & Environment Initialization
#
# This notebook covers the Exploratory Data Analysis (EDA) of the Leaf Disease Dataset.
# We will explore class distributions, image properties, and visual patterns.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from PIL import Image
import plotly.express as px
from tqdm import tqdm
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set_style('darkgrid')
